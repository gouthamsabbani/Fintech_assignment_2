# %%
pip install Quandl
# Out:
# Requirement already satisfied: Quandl in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (3.6.1)
# Requirement already satisfied: six in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (1.15.0)
# Requirement already satisfied: more-itertools in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (8.7.0)
# Requirement already satisfied: numpy>=1.8 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (1.20.1)
# Requirement already satisfied: inflection>=0.3.1 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (0.5.1)
# Requirement already satisfied: python-dateutil in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (2.8.1)
# Requirement already satisfied: pandas>=0.14 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (1.2.4)
# Requirement already satisfied: requests>=2.7.0 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from Quandl) (2.25.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.14->Quandl) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.0->Quandl) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.0->Quandl) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.0->Quandl) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.0->Quandl) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl
import numpy as np
import pandas as pd
import time
from datetime import date

# %%
import matplotlib.pyplot as plt

# %%
quandl.ApiConfig.api_key = 'NjpuaTu54EmEmmCGhGSZ'

# %%
Ibm = quandl.get('EOD/IBM',start_date='2013-01-01', end_date='2021-07-20')
Ibm
# Out:
#               Open    High     Low   Close     Volume  Dividend  Split  \
# Date
# 2013-09-03  183.63  184.32  182.51  183.96  3487200.0       0.0    1.0
# 2013-09-04  183.58  184.19  182.31  183.13  2597900.0       0.0    1.0
# 2013-09-05  183.35  185.00  183.07  184.15  2867600.0       0.0    1.0
# 2013-09-06  184.65  184.99  182.65  183.03  2903500.0       0.0    1.0
# 2013-09-09  183.68  185.49  183.31  184.98  3017200.0       0.0    1.0
# ...            ...     ...     ...     ...        ...       ...    ...
# 2017-12-21  153.17  153.46  151.49  151.50  4153665.0       0.0    1.0
# 2017-12-22  151.71  153.00  151.50  152.50  2987583.0       0.0    1.0
# 2017-12-26  152.51  153.86  152.50  152.83  2479017.0       0.0    1.0
# 2017-12-27  152.95  153.18  152.61  153.13  2149257.0       0.0    1.0
# 2017-12-28  153.20  154.12  153.20  154.04  2686989.0       0.0    1.0
#
#               Adj_Open    Adj_High     Adj_Low   Adj_Close  Adj_Volume
# Date
# 2013-09-03  134.021117  134.524709  133.203692  134.261965   3487200.0
# 2013-09-04  133.984625  134.429829  133.057724  133.656195   2597900.0
# 2013-09-05  133.816761  135.021002  133.612405  134.400635   2867600.0
# 2013-09-06  134.765557  135.013704  133.305870  133.583211   2903500.0
# 2013-09-09  134.057609  135.378625  133.787567  135.006405   3017200.0
# ...                ...         ...         ...         ...         ...
# 2017-12-21  128.175194  128.417871  126.769343  126.777711   4153665.0
# 2017-12-22  126.953442  128.032936  126.777711  127.614527   2987583.0
# 2017-12-26  127.622895  128.752598  127.614527  127.890677   2479017.0
# 2017-12-27  127.991095  128.183563  127.706577  128.141722   2149257.0
# 2017-12-28  128.200299  128.970170  128.200299  128.903225   2686989.0
#
# [1090 rows x 12 columns]

# %%
M = Ibm['Adj_Close']

# %%
M.head()
# Out:
# Date
# 2013-09-03    134.261965
# 2013-09-04    133.656195
# 2013-09-05    134.400635
# 2013-09-06    133.583211
# 2013-09-09    135.006405
# Name: Adj_Close, dtype: float64

# %%
int(time.mktime(time.strptime('2021-07-20', '%Y-%m-%d')))
# Out:
# 1626735600

# %%
pip install cryptocompare
# Out:
# Collecting cryptocompare
#   Downloading cryptocompare-0.7.5.tar.gz (5.2 kB)
# Requirement already satisfied: requests in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from cryptocompare) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests->cryptocompare) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests->cryptocompare) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests->cryptocompare) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/goutham/opt/anaconda3/lib/python3.8/site-packages (from requests->cryptocompare) (4.0.0)
# Building wheels for collected packages: cryptocompare
#   Building wheel for cryptocompare (setup.py) ... done
#   Created wheel for cryptocompare: filename=cryptocompare-0.7.5-py3-none-any.whl size=5066 sha256=fdaece141dd8b8aefad215c331b6ba448ccba4f7172cab37d7f256f8f23938f2
#   Stored in directory: /Users/goutham/Library/Caches/pip/wheels/17/5b/b7/0b29e1ef74d0be7fc02e164e2a974a189e0423b4300c529815
# Successfully built cryptocompare
# Installing collected packages: cryptocompare
# Successfully installed cryptocompare-0.7.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import requests

# %%
URL = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=BTC&tsym=USD&limit=2000&toTs=1626735600&api_key=a17f916d63008ee55b8c04bafc789e69a64ca8528cdfd1a562c4358457103bf0"

# %%
P = requests.get(URL)

# %%
btc = json.loads(P.text)
btc = btc['Data']
btc = btc['Data']
btc
# Out:
# [{'time': 1453852800,
#   'high': 397.37,
#   'low': 389.35,
#   'open': 389.78,
#   'volumefrom': 43678.72,
#   'volumeto': 17297117.36,
#   'close': 395.02,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1453939200,
#   'high': 395.42,
#   'low': 376.71,
#   'open': 395.02,
#   'volumefrom': 77319.55,
#   'volumeto': 29717813.05,
#   'close': 379.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454025600,
#   'high': 385.75,
#   'low': 363.49,
#   'open': 379.69,
#   'volumefrom': 138455.81,
#   'volumeto': 51927041.84,
#   'close': 380.29,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454112000,
#   'high': 381.75,
#   'low': 375.04,
#   'open': 380.29,
#   'volumefrom': 36179.6,
#   'volumeto': 13720656.84,
#   'close': 377.76,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454198400,
#   'high': 380.54,
#   'low': 366.88,
#   'open': 377.76,
#   'volumefrom': 39019.71,
#   'volumeto': 14718855.75,
#   'close': 369.84,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454284800,
#   'high': 379.78,
#   'low': 365.27,
#   'open': 369.84,
#   'volumefrom': 74346.01,
#   'volumeto': 27728088.91,
#   'close': 372.18,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454371200,
#   'high': 376.63,
#   'low': 371.4,
#   'open': 372.18,
#   'volumefrom': 50981.07,
#   'volumeto': 19123252.48,
#   'close': 373.92,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454457600,
#   'high': 375.89,
#   'low': 366.2,
#   'open': 373.92,
#   'volumefrom': 59813.05,
#   'volumeto': 22266682.14,
#   'close': 368.02,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454544000,
#   'high': 391.83,
#   'low': 368.05,
#   'open': 368.02,
#   'volumefrom': 101868.7,
#   'volumeto': 38961905.49,
#   'close': 390.65,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454630400,
#   'high': 391.15,
#   'low': 384.48,
#   'open': 390.65,
#   'volumefrom': 60917.35,
#   'volumeto': 23688228.07,
#   'close': 386.46,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454716800,
#   'high': 386.35,
#   'low': 372.87,
#   'open': 386.46,
#   'volumefrom': 78850.1,
#   'volumeto': 29801286.8,
#   'close': 376.68,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454803200,
#   'high': 382.61,
#   'low': 375.28,
#   'open': 376.68,
#   'volumefrom': 40743.17,
#   'volumeto': 15395728.35,
#   'close': 377.94,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454889600,
#   'high': 380.92,
#   'low': 372.1,
#   'open': 377.94,
#   'volumefrom': 62236.23,
#   'volumeto': 23424062.52,
#   'close': 372.63,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1454976000,
#   'high': 377.59,
#   'low': 371.42,
#   'open': 372.63,
#   'volumefrom': 55358.89,
#   'volumeto': 20801701.37,
#   'close': 375.32,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455062400,
#   'high': 385.38,
#   'low': 374.09,
#   'open': 375.32,
#   'volumefrom': 97487.81,
#   'volumeto': 37137791.06,
#   'close': 381.88,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455148800,
#   'high': 383.23,
#   'low': 372.75,
#   'open': 381.88,
#   'volumefrom': 62653.08,
#   'volumeto': 23858467.37,
#   'close': 379.45,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455235200,
#   'high': 386.4,
#   'low': 379.32,
#   'open': 379.45,
#   'volumefrom': 53759.93,
#   'volumeto': 20685663.27,
#   'close': 384.04,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455321600,
#   'high': 392.57,
#   'low': 383.31,
#   'open': 384.04,
#   'volumefrom': 48158.05,
#   'volumeto': 18757146.48,
#   'close': 390.1,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455408000,
#   'high': 405.93,
#   'low': 390.06,
#   'open': 390.1,
#   'volumefrom': 73589.64,
#   'volumeto': 29442484.67,
#   'close': 405.5,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455494400,
#   'high': 410.85,
#   'low': 396.56,
#   'open': 405.5,
#   'volumefrom': 86127.28,
#   'volumeto': 34862753.81,
#   'close': 401.07,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455580800,
#   'high': 409.75,
#   'low': 398,
#   'open': 401.07,
#   'volumefrom': 68330.32,
#   'volumeto': 27726590.05,
#   'close': 406.42,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455667200,
#   'high': 421.45,
#   'low': 405.05,
#   'open': 406.42,
#   'volumefrom': 90323.21,
#   'volumeto': 37559686.21,
#   'close': 417.14,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455753600,
#   'high': 425.51,
#   'low': 414.78,
#   'open': 417.14,
#   'volumefrom': 77346.22,
#   'volumeto': 32541108.12,
#   'close': 421.4,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455840000,
#   'high': 424.26,
#   'low': 416.36,
#   'open': 421.4,
#   'volumefrom': 52240.27,
#   'volumeto': 21991480.98,
#   'close': 419.98,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1455926400,
#   'high': 442.66,
#   'low': 419.49,
#   'open': 419.98,
#   'volumefrom': 111626.76,
#   'volumeto': 48500793.67,
#   'close': 440.06,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456012800,
#   'high': 447.61,
#   'low': 425.47,
#   'open': 440.06,
#   'volumefrom': 100499.03,
#   'volumeto': 44120520.96,
#   'close': 437.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456099200,
#   'high': 440.18,
#   'low': 431.3,
#   'open': 437.87,
#   'volumefrom': 56010.22,
#   'volumeto': 24563748.2,
#   'close': 437.79,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456185600,
#   'high': 440.76,
#   'low': 414.36,
#   'open': 437.79,
#   'volumefrom': 93717.62,
#   'volumeto': 39915706.29,
#   'close': 419.9,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456272000,
#   'high': 425.17,
#   'low': 410.36,
#   'open': 419.9,
#   'volumefrom': 66506.84,
#   'volumeto': 28041199.85,
#   'close': 422.72,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456358400,
#   'high': 427.18,
#   'low': 417.51,
#   'open': 422.72,
#   'volumefrom': 53541.45,
#   'volumeto': 22692099.41,
#   'close': 423.48,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456444800,
#   'high': 427.58,
#   'low': 419.11,
#   'open': 423.48,
#   'volumefrom': 53212.34,
#   'volumeto': 22642013.92,
#   'close': 427.32,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456531200,
#   'high': 434.14,
#   'low': 427.3,
#   'open': 427.32,
#   'volumefrom': 42792.33,
#   'volumeto': 18543436.43,
#   'close': 431.3,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456617600,
#   'high': 435.62,
#   'low': 421.22,
#   'open': 431.3,
#   'volumefrom': 50847.07,
#   'volumeto': 21876091.34,
#   'close': 432.47,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456704000,
#   'high': 441.32,
#   'low': 429.83,
#   'open': 432.47,
#   'volumefrom': 68773.52,
#   'volumeto': 30077319.62,
#   'close': 436.21,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456790400,
#   'high': 439.02,
#   'low': 428.49,
#   'open': 436.21,
#   'volumefrom': 67461.59,
#   'volumeto': 29312670.84,
#   'close': 434.04,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456876800,
#   'high': 435.91,
#   'low': 423.85,
#   'open': 434.04,
#   'volumefrom': 57744.55,
#   'volumeto': 24894311.79,
#   'close': 425.36,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1456963200,
#   'high': 425.83,
#   'low': 414.94,
#   'open': 425.36,
#   'volumefrom': 78902.45,
#   'volumeto': 33188751.08,
#   'close': 419.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457049600,
#   'high': 423.39,
#   'low': 407.2,
#   'open': 419.56,
#   'volumefrom': 75267.61,
#   'volumeto': 31416610.3,
#   'close': 409.48,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457136000,
#   'high': 410.06,
#   'low': 386.93,
#   'open': 409.48,
#   'volumefrom': 129149.15,
#   'volumeto': 51725937.08,
#   'close': 399,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457222400,
#   'high': 412.02,
#   'low': 393.09,
#   'open': 399,
#   'volumefrom': 62593.92,
#   'volumeto': 25324456.27,
#   'close': 405.96,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457308800,
#   'high': 416.58,
#   'low': 401.98,
#   'open': 405.96,
#   'volumefrom': 61774.07,
#   'volumeto': 25349627.97,
#   'close': 414.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457395200,
#   'high': 416.72,
#   'low': 408.42,
#   'open': 414.87,
#   'volumefrom': 53769.8,
#   'volumeto': 22204517.93,
#   'close': 411.9,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457481600,
#   'high': 414.88,
#   'low': 408.94,
#   'open': 411.9,
#   'volumefrom': 50919.66,
#   'volumeto': 21035428.97,
#   'close': 412.76,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457568000,
#   'high': 417.48,
#   'low': 410.27,
#   'open': 412.76,
#   'volumefrom': 55735.81,
#   'volumeto': 23114636.62,
#   'close': 415.83,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457654400,
#   'high': 422.4,
#   'low': 415.11,
#   'open': 415.83,
#   'volumefrom': 60632.19,
#   'volumeto': 25469781.33,
#   'close': 419.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457740800,
#   'high': 420.67,
#   'low': 407.03,
#   'open': 419.11,
#   'volumefrom': 59635.49,
#   'volumeto': 24660321.63,
#   'close': 410.36,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457827200,
#   'high': 415.93,
#   'low': 409.57,
#   'open': 410.36,
#   'volumefrom': 34977.81,
#   'volumeto': 14457108,
#   'close': 412.41,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1457913600,
#   'high': 416.08,
#   'low': 411.19,
#   'open': 412.41,
#   'volumefrom': 49332.82,
#   'volumeto': 20471909.73,
#   'close': 414.31,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458000000,
#   'high': 417.37,
#   'low': 412.31,
#   'open': 414.31,
#   'volumefrom': 48596.63,
#   'volumeto': 20227610.88,
#   'close': 415.13,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458086400,
#   'high': 416.95,
#   'low': 413.32,
#   'open': 415.13,
#   'volumefrom': 44535.24,
#   'volumeto': 18509954.18,
#   'close': 415.91,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458172800,
#   'high': 419.56,
#   'low': 415.33,
#   'open': 415.91,
#   'volumefrom': 43820.66,
#   'volumeto': 18409340.68,
#   'close': 418.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458259200,
#   'high': 418.58,
#   'low': 402.48,
#   'open': 418.16,
#   'volumefrom': 66068.03,
#   'volumeto': 27178165.73,
#   'close': 408.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458345600,
#   'high': 410.49,
#   'low': 402.13,
#   'open': 408.16,
#   'volumefrom': 36997.54,
#   'volumeto': 15084656.26,
#   'close': 408.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458432000,
#   'high': 413.45,
#   'low': 407.24,
#   'open': 408.69,
#   'volumefrom': 30543.21,
#   'volumeto': 12577521.63,
#   'close': 411.53,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458518400,
#   'high': 413.09,
#   'low': 407.25,
#   'open': 411.53,
#   'volumefrom': 43159.26,
#   'volumeto': 17735457.25,
#   'close': 411.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458604800,
#   'high': 417.94,
#   'low': 410.78,
#   'open': 411.11,
#   'volumefrom': 49075.11,
#   'volumeto': 20425092.47,
#   'close': 416.21,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458691200,
#   'high': 419.58,
#   'low': 414.18,
#   'open': 416.21,
#   'volumefrom': 40605.05,
#   'volumeto': 16946522.38,
#   'close': 416.98,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458777600,
#   'high': 417.68,
#   'low': 412.88,
#   'open': 416.98,
#   'volumefrom': 38828.43,
#   'volumeto': 16210672.62,
#   'close': 414.74,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458864000,
#   'high': 417.3,
#   'low': 412.41,
#   'open': 414.74,
#   'volumefrom': 34588.15,
#   'volumeto': 14431200.38,
#   'close': 415.71,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1458950400,
#   'high': 417.71,
#   'low': 413.93,
#   'open': 415.71,
#   'volumefrom': 28056.64,
#   'volumeto': 11696306.67,
#   'close': 416.51,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459036800,
#   'high': 427.36,
#   'low': 415.5,
#   'open': 416.51,
#   'volumefrom': 61724.4,
#   'volumeto': 26137150.51,
#   'close': 424.57,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459123200,
#   'high': 425.36,
#   'low': 419.7,
#   'open': 424.57,
#   'volumefrom': 43444.76,
#   'volumeto': 18410749.99,
#   'close': 422.21,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459209600,
#   'high': 424.53,
#   'low': 406.36,
#   'open': 422.21,
#   'volumefrom': 69113.03,
#   'volumeto': 28765857.05,
#   'close': 415,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459296000,
#   'high': 416.22,
#   'low': 408.4,
#   'open': 415,
#   'volumefrom': 43282.31,
#   'volumeto': 17890792.61,
#   'close': 412.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459382400,
#   'high': 417.16,
#   'low': 411.45,
#   'open': 412.44,
#   'volumefrom': 41840.9,
#   'volumeto': 17407273.19,
#   'close': 415.66,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459468800,
#   'high': 416.86,
#   'low': 412.79,
#   'open': 415.66,
#   'volumefrom': 38218.91,
#   'volumeto': 15852511.01,
#   'close': 415.64,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459555200,
#   'high': 420.09,
#   'low': 415.09,
#   'open': 415.64,
#   'volumefrom': 31309.25,
#   'volumeto': 13137339.89,
#   'close': 418.51,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459641600,
#   'high': 420.18,
#   'low': 416.95,
#   'open': 418.51,
#   'volumefrom': 22798.16,
#   'volumeto': 9591214.82,
#   'close': 419.06,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459728000,
#   'high': 420.39,
#   'low': 416.21,
#   'open': 419.06,
#   'volumefrom': 33436.9,
#   'volumeto': 14031939.65,
#   'close': 419.33,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459814400,
#   'high': 423.67,
#   'low': 417.95,
#   'open': 419.33,
#   'volumefrom': 40886.78,
#   'volumeto': 17260368.39,
#   'close': 422.07,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459900800,
#   'high': 422.81,
#   'low': 419.54,
#   'open': 422.07,
#   'volumefrom': 32667.23,
#   'volumeto': 13836754.91,
#   'close': 421.26,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1459987200,
#   'high': 422.03,
#   'low': 417.94,
#   'open': 421.26,
#   'volumefrom': 36056.99,
#   'volumeto': 15200495.86,
#   'close': 420.14,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460073600,
#   'high': 423.51,
#   'low': 415.5,
#   'open': 420.14,
#   'volumefrom': 46947.25,
#   'volumeto': 19810838.26,
#   'close': 417.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460160000,
#   'high': 418.85,
#   'low': 412.39,
#   'open': 417.69,
#   'volumefrom': 29424.6,
#   'volumeto': 12291880.83,
#   'close': 418.05,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460246400,
#   'high': 421.63,
#   'low': 416.69,
#   'open': 418.05,
#   'volumefrom': 23300.23,
#   'volumeto': 9806327.9,
#   'close': 420.25,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460332800,
#   'high': 422.35,
#   'low': 418.11,
#   'open': 420.25,
#   'volumefrom': 36387.29,
#   'volumeto': 15374195.04,
#   'close': 421.43,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460419200,
#   'high': 426.69,
#   'low': 420.7,
#   'open': 421.43,
#   'volumefrom': 57711.94,
#   'volumeto': 24580503.64,
#   'close': 424.74,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460505600,
#   'high': 426.58,
#   'low': 421.41,
#   'open': 424.74,
#   'volumefrom': 38088.6,
#   'volumeto': 16183793.93,
#   'close': 423.47,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460592000,
#   'high': 425.44,
#   'low': 421.84,
#   'open': 423.47,
#   'volumefrom': 30664.4,
#   'volumeto': 13038970.54,
#   'close': 424.02,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460678400,
#   'high': 429.49,
#   'low': 423.25,
#   'open': 424.02,
#   'volumefrom': 54119.98,
#   'volumeto': 23214560.1,
#   'close': 428.67,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460764800,
#   'high': 432,
#   'low': 426.84,
#   'open': 428.67,
#   'volumefrom': 29021.18,
#   'volumeto': 12517265.78,
#   'close': 430.05,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460851200,
#   'high': 430.62,
#   'low': 423.79,
#   'open': 430.05,
#   'volumefrom': 25586.86,
#   'volumeto': 10980868.31,
#   'close': 426.26,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1460937600,
#   'high': 429.07,
#   'low': 424.35,
#   'open': 426.26,
#   'volumefrom': 32574.71,
#   'volumeto': 13951524.85,
#   'close': 427.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461024000,
#   'high': 436.07,
#   'low': 426.84,
#   'open': 427.69,
#   'volumefrom': 45675.4,
#   'volumeto': 19713466.34,
#   'close': 434.92,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461110400,
#   'high': 442.86,
#   'low': 432.51,
#   'open': 434.92,
#   'volumefrom': 74361.53,
#   'volumeto': 32655415.81,
#   'close': 441.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461196800,
#   'high': 450.8,
#   'low': 439.53,
#   'open': 441.16,
#   'volumefrom': 63127.8,
#   'volumeto': 28168774.29,
#   'close': 449.34,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461283200,
#   'high': 450.19,
#   'low': 441.9,
#   'open': 449.34,
#   'volumefrom': 49710.33,
#   'volumeto': 22225157.27,
#   'close': 445.28,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461369600,
#   'high': 451.48,
#   'low': 443.07,
#   'open': 445.28,
#   'volumefrom': 42358.77,
#   'volumeto': 18998211.55,
#   'close': 450.08,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461456000,
#   'high': 461.78,
#   'low': 447.89,
#   'open': 450.08,
#   'volumefrom': 74434.28,
#   'volumeto': 33984269.34,
#   'close': 457.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461542400,
#   'high': 466.23,
#   'low': 451.79,
#   'open': 457.56,
#   'volumefrom': 81656.03,
#   'volumeto': 37614684.81,
#   'close': 461.73,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461628800,
#   'high': 468.86,
#   'low': 459.23,
#   'open': 461.73,
#   'volumefrom': 67557.86,
#   'volumeto': 31451239.15,
#   'close': 466,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461715200,
#   'high': 467.87,
#   'low': 444.62,
#   'open': 466,
#   'volumefrom': 90806.31,
#   'volumeto': 41539684.76,
#   'close': 447.01,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461801600,
#   'high': 450.1,
#   'low': 433.9,
#   'open': 447.01,
#   'volumefrom': 81934.58,
#   'volumeto': 36369788.38,
#   'close': 448.48,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461888000,
#   'high': 456.31,
#   'low': 445.22,
#   'open': 448.48,
#   'volumefrom': 44850.72,
#   'volumeto': 20264761.95,
#   'close': 454.98,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1461974400,
#   'high': 456.86,
#   'low': 446.65,
#   'open': 454.98,
#   'volumefrom': 35308.4,
#   'volumeto': 15994805.53,
#   'close': 448.53,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462060800,
#   'high': 454.21,
#   'low': 447.52,
#   'open': 448.53,
#   'volumefrom': 21745.59,
#   'volumeto': 9838490.74,
#   'close': 452.24,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462147200,
#   'high': 453.87,
#   'low': 440.21,
#   'open': 452.24,
#   'volumefrom': 73854.48,
#   'volumeto': 32863011.95,
#   'close': 444.18,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462233600,
#   'high': 451.54,
#   'low': 441.55,
#   'open': 444.18,
#   'volumefrom': 49749.84,
#   'volumeto': 22292253.48,
#   'close': 450.27,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462320000,
#   'high': 450.87,
#   'low': 444.22,
#   'open': 450.27,
#   'volumefrom': 39440.84,
#   'volumeto': 17676609.71,
#   'close': 445.8,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462406400,
#   'high': 449.19,
#   'low': 444.35,
#   'open': 445.8,
#   'volumefrom': 41887.49,
#   'volumeto': 18765369.38,
#   'close': 448.08,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462492800,
#   'high': 461.48,
#   'low': 445.72,
#   'open': 448.08,
#   'volumefrom': 68429.7,
#   'volumeto': 31122708.07,
#   'close': 459.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462579200,
#   'high': 460.61,
#   'low': 454.6,
#   'open': 459.56,
#   'volumefrom': 30971.06,
#   'volumeto': 14247601.97,
#   'close': 458.46,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462665600,
#   'high': 460.18,
#   'low': 454.94,
#   'open': 458.46,
#   'volumefrom': 27597.1,
#   'volumeto': 12689581.18,
#   'close': 457.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462752000,
#   'high': 464.18,
#   'low': 455.38,
#   'open': 457.87,
#   'volumefrom': 48422.16,
#   'volumeto': 22322043.96,
#   'close': 460.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462838400,
#   'high': 462.14,
#   'low': 446.81,
#   'open': 460.44,
#   'volumefrom': 59992.45,
#   'volumeto': 27247925.23,
#   'close': 449.36,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1462924800,
#   'high': 456.15,
#   'low': 449.59,
#   'open': 449.36,
#   'volumefrom': 39965.14,
#   'volumeto': 18137209.37,
#   'close': 452.5,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463011200,
#   'high': 455.34,
#   'low': 448.4,
#   'open': 452.5,
#   'volumefrom': 49186.86,
#   'volumeto': 22252919.49,
#   'close': 454.43,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463097600,
#   'high': 457.22,
#   'low': 451.49,
#   'open': 454.43,
#   'volumefrom': 32389.98,
#   'volumeto': 14768796.02,
#   'close': 455.41,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463184000,
#   'high': 457.74,
#   'low': 453.58,
#   'open': 455.41,
#   'volumefrom': 20360.7,
#   'volumeto': 9319128.91,
#   'close': 456.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463270400,
#   'high': 460.28,
#   'low': 455,
#   'open': 456.44,
#   'volumefrom': 21196.42,
#   'volumeto': 9745309.9,
#   'close': 458.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463356800,
#   'high': 459.57,
#   'low': 450.73,
#   'open': 458.11,
#   'volumefrom': 36601.5,
#   'volumeto': 16731954.01,
#   'close': 454.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463443200,
#   'high': 456.3,
#   'low': 451.71,
#   'open': 454.87,
#   'volumefrom': 34628.34,
#   'volumeto': 15741822.36,
#   'close': 453.25,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463529600,
#   'high': 456.65,
#   'low': 452.35,
#   'open': 453.25,
#   'volumefrom': 32606.95,
#   'volumeto': 14884550.93,
#   'close': 454.22,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463616000,
#   'high': 455.19,
#   'low': 441.12,
#   'open': 454.22,
#   'volumefrom': 59385.1,
#   'volumeto': 26626097.5,
#   'close': 442.66,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463702400,
#   'high': 447.76,
#   'low': 435.42,
#   'open': 442.66,
#   'volumefrom': 48431.62,
#   'volumeto': 21415312.04,
#   'close': 442.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463788800,
#   'high': 445.24,
#   'low': 439.73,
#   'open': 442.11,
#   'volumefrom': 22999.29,
#   'volumeto': 10213550.36,
#   'close': 443.64,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463875200,
#   'high': 444.24,
#   'low': 436.94,
#   'open': 443.64,
#   'volumefrom': 28739.45,
#   'volumeto': 12691382.29,
#   'close': 439.62,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1463961600,
#   'high': 444.99,
#   'low': 438.24,
#   'open': 439.62,
#   'volumefrom': 35897.23,
#   'volumeto': 15885933.69,
#   'close': 443.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464048000,
#   'high': 447.9,
#   'low': 442.02,
#   'open': 443.69,
#   'volumefrom': 33214.62,
#   'volumeto': 14837671.76,
#   'close': 446.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464134400,
#   'high': 451.21,
#   'low': 445.35,
#   'open': 446.11,
#   'volumefrom': 37716.29,
#   'volumeto': 16954105.43,
#   'close': 449.78,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464220800,
#   'high': 454.25,
#   'low': 447.67,
#   'open': 449.78,
#   'volumefrom': 37715.9,
#   'volumeto': 17093327.23,
#   'close': 453.3,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464307200,
#   'high': 479.22,
#   'low': 452.71,
#   'open': 453.3,
#   'volumefrom': 135674.57,
#   'volumeto': 63894987.38,
#   'close': 474.05,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464393600,
#   'high': 531.76,
#   'low': 467.05,
#   'open': 474.05,
#   'volumefrom': 150172.04,
#   'volumeto': 75400711.07,
#   'close': 524.22,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464480000,
#   'high': 548.04,
#   'low': 493.22,
#   'open': 524.22,
#   'volumefrom': 152570.22,
#   'volumeto': 80753301.33,
#   'close': 516.05,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464566400,
#   'high': 544.18,
#   'low': 512.81,
#   'open': 516.05,
#   'volumefrom': 77528.43,
#   'volumeto': 41433165.43,
#   'close': 532.26,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464652800,
#   'high': 546.92,
#   'low': 513.15,
#   'open': 532.26,
#   'volumefrom': 114080.03,
#   'volumeto': 60896411.69,
#   'close': 528.92,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464739200,
#   'high': 542.26,
#   'low': 521.3,
#   'open': 528.92,
#   'volumefrom': 72406.45,
#   'volumeto': 38742660.86,
#   'close': 537.4,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464825600,
#   'high': 541.55,
#   'low': 530.47,
#   'open': 537.4,
#   'volumefrom': 52877.98,
#   'volumeto': 28380698.71,
#   'close': 537.1,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464912000,
#   'high': 573.72,
#   'low': 534.34,
#   'open': 537.1,
#   'volumefrom': 106250.27,
#   'volumeto': 59464310.87,
#   'close': 567.03,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1464998400,
#   'high': 592.68,
#   'low': 560.87,
#   'open': 567.03,
#   'volumefrom': 87411.46,
#   'volumeto': 50353517.34,
#   'close': 571.95,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465084800,
#   'high': 583.64,
#   'low': 567.77,
#   'open': 571.95,
#   'volumefrom': 64520.22,
#   'volumeto': 37233994.18,
#   'close': 574.91,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465171200,
#   'high': 586.73,
#   'low': 571.67,
#   'open': 574.91,
#   'volumefrom': 63682.81,
#   'volumeto': 37131086.56,
#   'close': 583.58,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465257600,
#   'high': 591.32,
#   'low': 543.63,
#   'open': 583.58,
#   'volumefrom': 84694.25,
#   'volumeto': 49082472.71,
#   'close': 575.58,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465344000,
#   'high': 582.44,
#   'low': 567.78,
#   'open': 575.58,
#   'volumefrom': 49604.16,
#   'volumeto': 28706216.31,
#   'close': 580.51,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465430400,
#   'high': 580.71,
#   'low': 569.26,
#   'open': 580.51,
#   'volumefrom': 48613.35,
#   'volumeto': 28010575.91,
#   'close': 574.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465516800,
#   'high': 579.26,
#   'low': 571.14,
#   'open': 574.69,
#   'volumefrom': 45501.86,
#   'volumeto': 26290866.62,
#   'close': 577.89,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465603200,
#   'high': 592.61,
#   'low': 576.29,
#   'open': 577.89,
#   'volumefrom': 42217.02,
#   'volumeto': 24790441.26,
#   'close': 591.6,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465689600,
#   'high': 683.85,
#   'low': 592.79,
#   'open': 591.6,
#   'volumefrom': 217379.53,
#   'volumeto': 139684630.33,
#   'close': 666.55,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465776000,
#   'high': 718.24,
#   'low': 652.78,
#   'open': 666.55,
#   'volumefrom': 216731.32,
#   'volumeto': 149442548.73,
#   'close': 700.07,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465862400,
#   'high': 702.52,
#   'low': 654.69,
#   'open': 700.07,
#   'volumefrom': 135648.79,
#   'volumeto': 92458349.24,
#   'close': 685.14,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1465948800,
#   'high': 695.07,
#   'low': 670.45,
#   'open': 685.14,
#   'volumefrom': 78620.97,
#   'volumeto': 53863568.9,
#   'close': 690.77,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466035200,
#   'high': 769.73,
#   'low': 687.43,
#   'open': 690.77,
#   'volumefrom': 229569.22,
#   'volumeto': 169704647.02,
#   'close': 761.21,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466121600,
#   'high': 771.89,
#   'low': 704.21,
#   'open': 761.21,
#   'volumefrom': 215870.36,
#   'volumeto': 160302360.32,
#   'close': 743.9,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466208000,
#   'high': 776.04,
#   'low': 727.13,
#   'open': 743.9,
#   'volumefrom': 120525.37,
#   'volumeto': 91056993.79,
#   'close': 753.77,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466294400,
#   'high': 765.1,
#   'low': 740.38,
#   'open': 753.77,
#   'volumefrom': 60445.37,
#   'volumeto': 45805980.62,
#   'close': 761.04,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466380800,
#   'high': 764.6,
#   'low': 717.41,
#   'open': 761.04,
#   'volumefrom': 112290.09,
#   'volumeto': 83637617.46,
#   'close': 733.97,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466467200,
#   'high': 732.23,
#   'low': 626.05,
#   'open': 733.97,
#   'volumefrom': 248083.39,
#   'volumeto': 166828425.88,
#   'close': 667.38,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466553600,
#   'high': 677.8,
#   'low': 586.6,
#   'open': 667.38,
#   'volumefrom': 202320.1,
#   'volumeto': 129550795.89,
#   'close': 590.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466640000,
#   'high': 629.55,
#   'low': 539.28,
#   'open': 590.56,
#   'volumefrom': 261739.44,
#   'volumeto': 154289129.68,
#   'close': 620.84,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466726400,
#   'high': 687.39,
#   'low': 616.41,
#   'open': 620.84,
#   'volumefrom': 196694.45,
#   'volumeto': 128990817.06,
#   'close': 656.89,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466812800,
#   'high': 688.1,
#   'low': 640.79,
#   'open': 656.89,
#   'volumefrom': 100457.69,
#   'volumeto': 67442141.07,
#   'close': 663.52,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466899200,
#   'high': 665.19,
#   'low': 609.9,
#   'open': 663.52,
#   'volumefrom': 88928.71,
#   'volumeto': 56403088.15,
#   'close': 625.41,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1466985600,
#   'high': 650.34,
#   'low': 615.22,
#   'open': 625.41,
#   'volumefrom': 99812.97,
#   'volumeto': 63747137.15,
#   'close': 644.66,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467072000,
#   'high': 659.27,
#   'low': 634.26,
#   'open': 644.66,
#   'volumefrom': 76657.93,
#   'volumeto': 49673830.24,
#   'close': 644.89,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467158400,
#   'high': 645.91,
#   'low': 621.76,
#   'open': 644.89,
#   'volumefrom': 80218.82,
#   'volumeto': 50898093.64,
#   'close': 636.54,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467244800,
#   'high': 673.04,
#   'low': 631.24,
#   'open': 636.54,
#   'volumefrom': 88203.81,
#   'volumeto': 58215062.66,
#   'close': 670.02,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467331200,
#   'high': 685.11,
#   'low': 661.09,
#   'open': 670.02,
#   'volumefrom': 92227.36,
#   'volumeto': 62394480.64,
#   'close': 674.57,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467417600,
#   'high': 700.46,
#   'low': 671.46,
#   'open': 674.57,
#   'volumefrom': 67380.47,
#   'volumeto': 46555796.93,
#   'close': 698.06,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467504000,
#   'high': 701.49,
#   'low': 644.61,
#   'open': 698.06,
#   'volumefrom': 99268.29,
#   'volumeto': 66591456.99,
#   'close': 661.64,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467590400,
#   'high': 679.03,
#   'low': 644.04,
#   'open': 661.64,
#   'volumefrom': 63905.01,
#   'volumeto': 42756935.48,
#   'close': 675.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467676800,
#   'high': 679.19,
#   'low': 657.31,
#   'open': 675.16,
#   'volumefrom': 54642.8,
#   'volumeto': 36687264.23,
#   'close': 663.67,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467763200,
#   'high': 678.39,
#   'low': 662.24,
#   'open': 663.67,
#   'volumefrom': 47049.5,
#   'volumeto': 31708100.51,
#   'close': 672.7,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467849600,
#   'high': 676.19,
#   'low': 604.95,
#   'open': 672.7,
#   'volumefrom': 153608.21,
#   'volumeto': 97639342.03,
#   'close': 635.25,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1467936000,
#   'high': 663.43,
#   'low': 630.17,
#   'open': 635.25,
#   'volumefrom': 75892.55,
#   'volumeto': 49243011.02,
#   'close': 662.78,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468022400,
#   'high': 663.49,
#   'low': 620.68,
#   'open': 662.78,
#   'volumefrom': 96013.13,
#   'volumeto': 62061207.33,
#   'close': 651.83,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468108800,
#   'high': 651.98,
#   'low': 636.8,
#   'open': 651.83,
#   'volumefrom': 29256.82,
#   'volumeto': 18955766.48,
#   'close': 647.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468195200,
#   'high': 657.47,
#   'low': 639.97,
#   'open': 647.11,
#   'volumefrom': 45941.77,
#   'volumeto': 29925667.34,
#   'close': 646.71,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468281600,
#   'high': 673.19,
#   'low': 644.56,
#   'open': 646.71,
#   'volumefrom': 66591.48,
#   'volumeto': 44047499.67,
#   'close': 670.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468368000,
#   'high': 672.02,
#   'low': 656.04,
#   'open': 670.56,
#   'volumefrom': 62958.21,
#   'volumeto': 41791464.25,
#   'close': 661.15,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468454400,
#   'high': 661.88,
#   'low': 646.31,
#   'open': 661.15,
#   'volumefrom': 48196.92,
#   'volumeto': 31748496.83,
#   'close': 657.25,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468540800,
#   'high': 667.46,
#   'low': 656.5,
#   'open': 657.25,
#   'volumefrom': 35830.56,
#   'volumeto': 23817856.65,
#   'close': 664.2,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468627200,
#   'high': 665.41,
#   'low': 655.72,
#   'open': 664.2,
#   'volumefrom': 20385,
#   'volumeto': 13557557.05,
#   'close': 660.69,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468713600,
#   'high': 680.94,
#   'low': 660.13,
#   'open': 660.69,
#   'volumefrom': 46840.6,
#   'volumeto': 31614610.5,
#   'close': 676.33,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468800000,
#   'high': 680.42,
#   'low': 664.61,
#   'open': 676.33,
#   'volumefrom': 42576.77,
#   'volumeto': 28810844.41,
#   'close': 670.38,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468886400,
#   'high': 673.24,
#   'low': 663.63,
#   'open': 670.38,
#   'volumefrom': 30395.36,
#   'volumeto': 20401885.27,
#   'close': 671.1,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1468972800,
#   'high': 672.29,
#   'low': 659.51,
#   'open': 671.1,
#   'volumefrom': 37562.71,
#   'volumeto': 25075066.39,
#   'close': 664.4,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469059200,
#   'high': 666.51,
#   'low': 657.82,
#   'open': 664.4,
#   'volumefrom': 32164.64,
#   'volumeto': 21351309.78,
#   'close': 664.62,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469145600,
#   'high': 669.44,
#   'low': 645.69,
#   'open': 664.62,
#   'volumefrom': 65894.84,
#   'volumeto': 43283429.35,
#   'close': 651.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469232000,
#   'high': 658.17,
#   'low': 647.98,
#   'open': 651.11,
#   'volumefrom': 29884.68,
#   'volumeto': 19544654.54,
#   'close': 655.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469318400,
#   'high': 664.21,
#   'low': 651.03,
#   'open': 655.16,
#   'volumefrom': 29815.62,
#   'volumeto': 19642346.73,
#   'close': 659.29,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469404800,
#   'high': 662.51,
#   'low': 651.08,
#   'open': 659.29,
#   'volumefrom': 34383.06,
#   'volumeto': 22564554.46,
#   'close': 654,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469491200,
#   'high': 657.76,
#   'low': 643.49,
#   'open': 654,
#   'volumefrom': 49388.21,
#   'volumeto': 32177578.58,
#   'close': 654.38,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469577600,
#   'high': 659.08,
#   'low': 646.04,
#   'open': 654.38,
#   'volumefrom': 29885.7,
#   'volumeto': 19568531.49,
#   'close': 654.54,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469664000,
#   'high': 657.96,
#   'low': 650.81,
#   'open': 654.54,
#   'volumefrom': 28112.8,
#   'volumeto': 18452583.66,
#   'close': 654.13,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469750400,
#   'high': 657.4,
#   'low': 650.99,
#   'open': 654.13,
#   'volumefrom': 27043.62,
#   'volumeto': 17757920.48,
#   'close': 655.43,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469836800,
#   'high': 657.55,
#   'low': 652.06,
#   'open': 655.43,
#   'volumefrom': 19354.41,
#   'volumeto': 12721755.54,
#   'close': 654.74,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1469923200,
#   'high': 654.92,
#   'low': 621.42,
#   'open': 654.74,
#   'volumefrom': 62887.74,
#   'volumeto': 39918066.14,
#   'close': 621.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470009600,
#   'high': 627.89,
#   'low': 603.55,
#   'open': 621.87,
#   'volumefrom': 66660.27,
#   'volumeto': 41229298.83,
#   'close': 607,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470096000,
#   'high': 613.75,
#   'low': 471.36,
#   'open': 607,
#   'volumefrom': 130913.66,
#   'volumeto': 75338595.54,
#   'close': 513.43,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470182400,
#   'high': 573.06,
#   'low': 514.09,
#   'open': 513.43,
#   'volumefrom': 85930.35,
#   'volumeto': 47170751.56,
#   'close': 566.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470268800,
#   'high': 584.89,
#   'low': 559.5,
#   'open': 566.44,
#   'volumefrom': 44823.44,
#   'volumeto': 25725471.16,
#   'close': 576.22,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470355200,
#   'high': 579.97,
#   'low': 565.81,
#   'open': 576.22,
#   'volumefrom': 27885.51,
#   'volumeto': 15992890.37,
#   'close': 574.66,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470441600,
#   'high': 596.68,
#   'low': 565.33,
#   'open': 574.66,
#   'volumefrom': 25382.28,
#   'volumeto': 14676841.26,
#   'close': 586.45,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470528000,
#   'high': 596.01,
#   'low': 580.87,
#   'open': 586.45,
#   'volumefrom': 26202.24,
#   'volumeto': 15491523.1,
#   'close': 590.85,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470614400,
#   'high': 594.24,
#   'low': 585.41,
#   'open': 590.85,
#   'volumefrom': 24880.83,
#   'volumeto': 14726811.56,
#   'close': 589.24,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470700800,
#   'high': 591.2,
#   'low': 581.1,
#   'open': 589.24,
#   'volumefrom': 25971.47,
#   'volumeto': 15304277.91,
#   'close': 585.25,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470787200,
#   'high': 600.52,
#   'low': 580.87,
#   'open': 585.25,
#   'volumefrom': 49568.68,
#   'volumeto': 29376783.81,
#   'close': 590.94,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470873600,
#   'high': 599.15,
#   'low': 585.39,
#   'open': 590.94,
#   'volumefrom': 39824.58,
#   'volumeto': 23640952.51,
#   'close': 587.84,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1470960000,
#   'high': 591.14,
#   'low': 582.2,
#   'open': 587.84,
#   'volumefrom': 25501.78,
#   'volumeto': 15009452.98,
#   'close': 587.14,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471046400,
#   'high': 590.07,
#   'low': 582.81,
#   'open': 587.14,
#   'volumefrom': 19303.82,
#   'volumeto': 11357750.81,
#   'close': 584.59,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471132800,
#   'high': 585.8,
#   'low': 559.93,
#   'open': 584.59,
#   'volumefrom': 33065.8,
#   'volumeto': 18970094.63,
#   'close': 569.06,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471219200,
#   'high': 574.97,
#   'low': 559.28,
#   'open': 569.06,
#   'volumefrom': 33771.15,
#   'volumeto': 19218972.96,
#   'close': 566.95,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471305600,
#   'high': 583.38,
#   'low': 563.38,
#   'open': 566.95,
#   'volumefrom': 37689.33,
#   'volumeto': 21634083.15,
#   'close': 580.19,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471392000,
#   'high': 581.1,
#   'low': 568.66,
#   'open': 580.19,
#   'volumefrom': 32760.8,
#   'volumeto': 18886741.55,
#   'close': 572.34,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471478400,
#   'high': 579.53,
#   'low': 570.83,
#   'open': 572.34,
#   'volumefrom': 30389.41,
#   'volumeto': 17509679.71,
#   'close': 573.39,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471564800,
#   'high': 577.86,
#   'low': 566.25,
#   'open': 573.39,
#   'volumefrom': 25530.44,
#   'volumeto': 14701426.29,
#   'close': 574.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471651200,
#   'high': 583.5,
#   'low': 572.28,
#   'open': 574.56,
#   'volumefrom': 23119.79,
#   'volumeto': 13416843.63,
#   'close': 582.61,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471737600,
#   'high': 585.32,
#   'low': 577.84,
#   'open': 582.61,
#   'volumefrom': 14160.18,
#   'volumeto': 8294321.53,
#   'close': 580.66,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471824000,
#   'high': 591.9,
#   'low': 577.13,
#   'open': 580.66,
#   'volumefrom': 33558.61,
#   'volumeto': 19658058.08,
#   'close': 587.47,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471910400,
#   'high': 589.87,
#   'low': 578.61,
#   'open': 587.47,
#   'volumefrom': 32082.32,
#   'volumeto': 18772369.53,
#   'close': 583.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1471996800,
#   'high': 584.47,
#   'low': 576.82,
#   'open': 583.56,
#   'volumefrom': 28057.04,
#   'volumeto': 16337141.09,
#   'close': 579.66,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472083200,
#   'high': 580.71,
#   'low': 570.81,
#   'open': 579.66,
#   'volumefrom': 32733.65,
#   'volumeto': 18885349.63,
#   'close': 577.96,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472169600,
#   'high': 582.73,
#   'low': 575.83,
#   'open': 577.96,
#   'volumefrom': 21168.38,
#   'volumeto': 12329289.75,
#   'close': 579.37,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472256000,
#   'high': 580.41,
#   'low': 567.25,
#   'open': 579.37,
#   'volumefrom': 18686.65,
#   'volumeto': 10747219.53,
#   'close': 570.35,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472342400,
#   'high': 576.32,
#   'low': 569.21,
#   'open': 570.35,
#   'volumefrom': 12824.95,
#   'volumeto': 7377921.72,
#   'close': 574.98,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472428800,
#   'high': 578.61,
#   'low': 571.38,
#   'open': 574.98,
#   'volumefrom': 23862.95,
#   'volumeto': 13760854.22,
#   'close': 574.23,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472515200,
#   'high': 579.94,
#   'low': 572.51,
#   'open': 574.23,
#   'volumefrom': 27480.29,
#   'volumeto': 15895354.76,
#   'close': 577.32,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472601600,
#   'high': 578.25,
#   'low': 571.69,
#   'open': 577.32,
#   'volumefrom': 24933.77,
#   'volumeto': 14338795.45,
#   'close': 573.88,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472688000,
#   'high': 704.97,
#   'low': 569.37,
#   'open': 573.88,
#   'volumefrom': 25872.2,
#   'volumeto': 14860164.25,
#   'close': 571.99,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472774400,
#   'high': 577.6,
#   'low': 569.3,
#   'open': 571.99,
#   'volumefrom': 26612.15,
#   'volumeto': 15315755.66,
#   'close': 575.29,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472860800,
#   'high': 604.97,
#   'low': 572.64,
#   'open': 575.29,
#   'volumefrom': 35699.73,
#   'volumeto': 21055514.22,
#   'close': 598.84,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1472947200,
#   'high': 615.2,
#   'low': 590.78,
#   'open': 598.84,
#   'volumefrom': 30690.03,
#   'volumeto': 18646011.82,
#   'close': 609.55,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473033600,
#   'high': 610.61,
#   'low': 598.77,
#   'open': 609.55,
#   'volumefrom': 25286.46,
#   'volumeto': 15369832.26,
#   'close': 605.76,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473120000,
#   'high': 611.95,
#   'low': 603.55,
#   'open': 605.76,
#   'volumefrom': 24324.78,
#   'volumeto': 14864563.84,
#   'close': 610.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473206400,
#   'high': 616.48,
#   'low': 606.24,
#   'open': 610.44,
#   'volumefrom': 30033.77,
#   'volumeto': 18429525.07,
#   'close': 613.21,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473292800,
#   'high': 629.3,
#   'low': 611.25,
#   'open': 613.21,
#   'volumefrom': 36328.29,
#   'volumeto': 22710390.64,
#   'close': 625.57,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473379200,
#   'high': 627.58,
#   'low': 617.32,
#   'open': 625.57,
#   'volumefrom': 28333.32,
#   'volumeto': 17710151.19,
#   'close': 623.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473465600,
#   'high': 627.45,
#   'low': 621.07,
#   'open': 623.16,
#   'volumefrom': 15279.28,
#   'volumeto': 9600113.74,
#   'close': 624.52,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473552000,
#   'high': 630.77,
#   'low': 592.79,
#   'open': 624.52,
#   'volumefrom': 36543.99,
#   'volumeto': 22467346.61,
#   'close': 605.61,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473638400,
#   'high': 610.62,
#   'low': 603.03,
#   'open': 605.61,
#   'volumefrom': 27944.86,
#   'volumeto': 17058938.65,
#   'close': 607.98,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473724800,
#   'high': 612.03,
#   'low': 604.87,
#   'open': 607.98,
#   'volumefrom': 27515.13,
#   'volumeto': 16850869.45,
#   'close': 608.61,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473811200,
#   'high': 612.16,
#   'low': 606.39,
#   'open': 608.61,
#   'volumefrom': 24244.49,
#   'volumeto': 14878860.18,
#   'close': 609.54,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473897600,
#   'high': 610.73,
#   'low': 605.1,
#   'open': 609.54,
#   'volumefrom': 22687.24,
#   'volumeto': 13892193.46,
#   'close': 608.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1473984000,
#   'high': 610.36,
#   'low': 605.15,
#   'open': 608.11,
#   'volumefrom': 21847.03,
#   'volumeto': 13353736.94,
#   'close': 607.78,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1474070400,
#   'high': 609.61,
#   'low': 604.52,
#   'open': 607.78,
#   'volumefrom': 15894.29,
#   'volumeto': 9724490.11,
#   'close': 607.08,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1474156800,
#   'high': 612.38,
#   'low': 605.22,
#   'open': 607.08,
#   'volumefrom': 16329.91,
#   'volumeto': 10004923.58,
#   'close': 610.7,
#   'conversionType': 'direct',
# ...
#   'open': 6945.77,
#   'volumefrom': 82683.83,
#   'volumeto': 575690006.27,
#   'close': 6723.21,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1533686400,
#   'high': 6723.99,
#   'low': 6133.03,
#   'open': 6723.29,
#   'volumefrom': 130417.52,
#   'volumeto': 838853615.89,
#   'close': 6285.02,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1533772800,
#   'high': 6631.23,
#   'low': 6195.02,
#   'open': 6285.06,
#   'volumefrom': 89588.13,
#   'volumeto': 575748446.38,
#   'close': 6543.24,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1533859200,
#   'high': 6582.14,
#   'low': 6025.91,
#   'open': 6543.25,
#   'volumefrom': 100856.92,
#   'volumeto': 639457019.98,
#   'close': 6153.41,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1533945600,
#   'high': 6488.55,
#   'low': 6014.26,
#   'open': 6152.95,
#   'volumefrom': 87651.14,
#   'volumeto': 545722619.11,
#   'close': 6242.54,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534032000,
#   'high': 6483.39,
#   'low': 6176.89,
#   'open': 6242.53,
#   'volumefrom': 57916.23,
#   'volumeto': 366460108.69,
#   'close': 6322.92,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534118400,
#   'high': 6545.02,
#   'low': 6157.03,
#   'open': 6322.41,
#   'volumefrom': 71073.56,
#   'volumeto': 452431672.68,
#   'close': 6263.2,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534204800,
#   'high': 6266.5,
#   'low': 5891.87,
#   'open': 6263.2,
#   'volumefrom': 125196.64,
#   'volumeto': 759847789.73,
#   'close': 6199.6,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534291200,
#   'high': 6620.07,
#   'low': 6193.63,
#   'open': 6199.63,
#   'volumefrom': 132926.33,
#   'volumeto': 852103141.83,
#   'close': 6274.22,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534377600,
#   'high': 6478.07,
#   'low': 6217.33,
#   'open': 6274.22,
#   'volumefrom': 71357.92,
#   'volumeto': 454679037.36,
#   'close': 6323.81,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534464000,
#   'high': 6594.72,
#   'low': 6300.45,
#   'open': 6323.81,
#   'volumefrom': 73383.05,
#   'volumeto': 477089455.56,
#   'close': 6591.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534550400,
#   'high': 6622.16,
#   'low': 6322.44,
#   'open': 6591.18,
#   'volumefrom': 52093.8,
#   'volumeto': 336744293.81,
#   'close': 6405.71,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534636800,
#   'high': 6560.88,
#   'low': 6330.56,
#   'open': 6405.74,
#   'volumefrom': 39452.94,
#   'volumeto': 253984821.8,
#   'close': 6502.18,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534723200,
#   'high': 6537.54,
#   'low': 6248.39,
#   'open': 6502.24,
#   'volumefrom': 61983.28,
#   'volumeto': 397981291.82,
#   'close': 6269.9,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534809600,
#   'high': 6506.69,
#   'low': 6259.81,
#   'open': 6270.09,
#   'volumefrom': 61753.86,
#   'volumeto': 396746063.37,
#   'close': 6491.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534896000,
#   'high': 6890.79,
#   'low': 6264.34,
#   'open': 6491.09,
#   'volumefrom': 116096.61,
#   'volumeto': 764005011.18,
#   'close': 6366.13,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1534982400,
#   'high': 6575.28,
#   'low': 6356.96,
#   'open': 6366.14,
#   'volumefrom': 52740.3,
#   'volumeto': 340811486.77,
#   'close': 6538.95,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535068800,
#   'high': 6736.83,
#   'low': 6481.76,
#   'open': 6539.13,
#   'volumefrom': 58037.12,
#   'volumeto': 382456858.97,
#   'close': 6708.96,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535155200,
#   'high': 6808.89,
#   'low': 6684.19,
#   'open': 6708.94,
#   'volumefrom': 38189.09,
#   'volumeto': 258296664.16,
#   'close': 6749.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535241600,
#   'high': 6793.17,
#   'low': 6588.48,
#   'open': 6749.71,
#   'volumefrom': 39682.91,
#   'volumeto': 265820591.17,
#   'close': 6720.6,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535328000,
#   'high': 6944.21,
#   'low': 6674.84,
#   'open': 6720.6,
#   'volumefrom': 59984.28,
#   'volumeto': 405769271.5,
#   'close': 6915.73,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535414400,
#   'high': 7136.71,
#   'low': 6877.2,
#   'open': 6915.92,
#   'volumefrom': 69448.01,
#   'volumeto': 487789642,
#   'close': 7091.38,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535500800,
#   'high': 7137.47,
#   'low': 6944.76,
#   'open': 7091.38,
#   'volumefrom': 50361.95,
#   'volumeto': 356139022.3,
#   'close': 7052,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535587200,
#   'high': 7072.64,
#   'low': 6818.69,
#   'open': 7051.61,
#   'volumefrom': 61266.88,
#   'volumeto': 425475685.56,
#   'close': 6998.76,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535673600,
#   'high': 7096.73,
#   'low': 6903.08,
#   'open': 6998.76,
#   'volumefrom': 49774.38,
#   'volumeto': 349131152.81,
#   'close': 7026.96,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535760000,
#   'high': 7272.03,
#   'low': 7025.58,
#   'open': 7026.96,
#   'volumefrom': 41873.76,
#   'volumeto': 300301833.39,
#   'close': 7203.46,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535846400,
#   'high': 7384.38,
#   'low': 7144.71,
#   'open': 7203.46,
#   'volumefrom': 61424.38,
#   'volumeto': 447453370.83,
#   'close': 7301.26,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1535932800,
#   'high': 7350.58,
#   'low': 7204.89,
#   'open': 7301.25,
#   'volumefrom': 42451.23,
#   'volumeto': 309327793.27,
#   'close': 7270.05,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536019200,
#   'high': 7417.65,
#   'low': 7246.76,
#   'open': 7270.05,
#   'volumefrom': 46681.9,
#   'volumeto': 343762001.58,
#   'close': 7369.86,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536105600,
#   'high': 7401.43,
#   'low': 6694.06,
#   'open': 7369.89,
#   'volumefrom': 113370.51,
#   'volumeto': 797851163.66,
#   'close': 6705.03,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536192000,
#   'high': 6727.19,
#   'low': 6295.11,
#   'open': 6705.06,
#   'volumefrom': 127586.04,
#   'volumeto': 823309044.3,
#   'close': 6515.42,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536278400,
#   'high': 6549.39,
#   'low': 6345.48,
#   'open': 6515.42,
#   'volumefrom': 53170.79,
#   'volumeto': 344487244.01,
#   'close': 6411.78,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536364800,
#   'high': 6480.57,
#   'low': 6134.76,
#   'open': 6413.12,
#   'volumefrom': 49719.12,
#   'volumeto': 317380272.09,
#   'close': 6200.16,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536451200,
#   'high': 6451.25,
#   'low': 6161.83,
#   'open': 6200.23,
#   'volumefrom': 38701,
#   'volumeto': 244400344.41,
#   'close': 6249.07,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536537600,
#   'high': 6371.42,
#   'low': 6247.64,
#   'open': 6249.07,
#   'volumefrom': 50695.88,
#   'volumeto': 320435279.61,
#   'close': 6324.43,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536624000,
#   'high': 6415.51,
#   'low': 6199.19,
#   'open': 6324.43,
#   'volumefrom': 51401.22,
#   'volumeto': 324512939.85,
#   'close': 6295.54,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536710400,
#   'high': 6357.89,
#   'low': 6208.28,
#   'open': 6295.54,
#   'volumefrom': 52814.83,
#   'volumeto': 332537236.17,
#   'close': 6337.11,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536796800,
#   'high': 6534.89,
#   'low': 6337.08,
#   'open': 6337.08,
#   'volumefrom': 65684.53,
#   'volumeto': 425090869.76,
#   'close': 6492,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536883200,
#   'high': 6591.59,
#   'low': 6393.84,
#   'open': 6492.17,
#   'volumefrom': 58029.07,
#   'volumeto': 377989402.01,
#   'close': 6486.01,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1536969600,
#   'high': 6573.19,
#   'low': 6473.47,
#   'open': 6485.39,
#   'volumefrom': 31894.67,
#   'volumeto': 208349557,
#   'close': 6522.08,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537056000,
#   'high': 6525.05,
#   'low': 6404.31,
#   'open': 6522.68,
#   'volumefrom': 30897.54,
#   'volumeto': 200545603.1,
#   'close': 6502.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537142400,
#   'high': 6538.82,
#   'low': 6216.83,
#   'open': 6502.44,
#   'volumefrom': 62738.57,
#   'volumeto': 399675966.34,
#   'close': 6261.48,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537228800,
#   'high': 6393.39,
#   'low': 6238.25,
#   'open': 6261.33,
#   'volumefrom': 55076.95,
#   'volumeto': 348485895.37,
#   'close': 6346.44,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537315200,
#   'high': 6522.9,
#   'low': 6131.02,
#   'open': 6346.44,
#   'volumefrom': 71293.01,
#   'volumeto': 452379323.08,
#   'close': 6398.8,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537401600,
#   'high': 6551.93,
#   'low': 6361.33,
#   'open': 6398.83,
#   'volumefrom': 46802.06,
#   'volumeto': 301619960.91,
#   'close': 6505.9,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537488000,
#   'high': 6785.22,
#   'low': 6501.01,
#   'open': 6505.97,
#   'volumefrom': 85295.46,
#   'volumeto': 569642976.25,
#   'close': 6762.06,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537574400,
#   'high': 6834.49,
#   'low': 6633.01,
#   'open': 6762.07,
#   'volumefrom': 38829.87,
#   'volumeto': 261159308.22,
#   'close': 6716.6,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537660800,
#   'high': 6768.56,
#   'low': 6663.9,
#   'open': 6716.6,
#   'volumefrom': 25143.83,
#   'volumeto': 169080003.37,
#   'close': 6702.7,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537747200,
#   'high': 6717.6,
#   'low': 6557.82,
#   'open': 6702.73,
#   'volumefrom': 48934.13,
#   'volumeto': 324660682.66,
#   'close': 6583.53,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537833600,
#   'high': 6583.54,
#   'low': 6333.21,
#   'open': 6583.53,
#   'volumefrom': 65381.85,
#   'volumeto': 420279170.44,
#   'close': 6437.74,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1537920000,
#   'high': 6543.92,
#   'low': 6383.16,
#   'open': 6437.74,
#   'volumefrom': 40752.6,
#   'volumeto': 264402806.65,
#   'close': 6462.6,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538006400,
#   'high': 6733.94,
#   'low': 6434.76,
#   'open': 6462.6,
#   'volumefrom': 52542,
#   'volumeto': 345096700.08,
#   'close': 6686.13,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538092800,
#   'high': 6806.1,
#   'low': 6545.41,
#   'open': 6686.13,
#   'volumefrom': 74353.41,
#   'volumeto': 497340510.07,
#   'close': 6635.38,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538179200,
#   'high': 6635.42,
#   'low': 6474.23,
#   'open': 6635.4,
#   'volumefrom': 37296.34,
#   'volumeto': 245055396.51,
#   'close': 6603.75,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538265600,
#   'high': 6741.96,
#   'low': 6543.68,
#   'open': 6603.75,
#   'volumefrom': 26335.14,
#   'volumeto': 174302164.09,
#   'close': 6623.71,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538352000,
#   'high': 6662.6,
#   'low': 6510.54,
#   'open': 6623.82,
#   'volumefrom': 38926.98,
#   'volumeto': 256959931.63,
#   'close': 6594.98,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538438400,
#   'high': 6618.95,
#   'low': 6478.04,
#   'open': 6594.98,
#   'volumefrom': 40624.2,
#   'volumeto': 267166277.79,
#   'close': 6525.47,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538524800,
#   'high': 6537.07,
#   'low': 6428.98,
#   'open': 6525.46,
#   'volumefrom': 47186,
#   'volumeto': 306385346.59,
#   'close': 6492.26,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538611200,
#   'high': 6622.32,
#   'low': 6486.86,
#   'open': 6492.61,
#   'volumefrom': 42142.96,
#   'volumeto': 277614018.45,
#   'close': 6579.79,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538697600,
#   'high': 6683.55,
#   'low': 6546.98,
#   'open': 6580,
#   'volumefrom': 39731.28,
#   'volumeto': 262562344.98,
#   'close': 6632.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538784000,
#   'high': 6637.08,
#   'low': 6563.25,
#   'open': 6632.88,
#   'volumefrom': 24787.61,
#   'volumeto': 162722103.98,
#   'close': 6589.94,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538870400,
#   'high': 6622.49,
#   'low': 6535.02,
#   'open': 6589.94,
#   'volumefrom': 27272.67,
#   'volumeto': 179378859.39,
#   'close': 6601.15,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1538956800,
#   'high': 6698.31,
#   'low': 6565.01,
#   'open': 6601.46,
#   'volumefrom': 47216.82,
#   'volumeto': 313507433.75,
#   'close': 6650.07,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539043200,
#   'high': 6657,
#   'low': 6589.39,
#   'open': 6650.07,
#   'volumefrom': 32204.25,
#   'volumeto': 213976678.23,
#   'close': 6631.79,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539129600,
#   'high': 6633.22,
#   'low': 6487.86,
#   'open': 6631.79,
#   'volumefrom': 49264.39,
#   'volumeto': 323664963.18,
#   'close': 6581.07,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539216000,
#   'high': 6581.59,
#   'low': 6171.95,
#   'open': 6581.07,
#   'volumefrom': 104258.49,
#   'volumeto': 654924117.8,
#   'close': 6209.47,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539302400,
#   'high': 6296.56,
#   'low': 6173.86,
#   'open': 6209.47,
#   'volumefrom': 46195.91,
#   'volumeto': 289840137.45,
#   'close': 6250.85,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539388800,
#   'high': 6280.73,
#   'low': 6238.92,
#   'open': 6252.1,
#   'volumefrom': 21914.85,
#   'volumeto': 137705035.59,
#   'close': 6267.27,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539475200,
#   'high': 6346.56,
#   'low': 6247.17,
#   'open': 6267.27,
#   'volumefrom': 34130.1,
#   'volumeto': 215422888.18,
#   'close': 6277.73,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539561600,
#   'high': 7234.83,
#   'low': 6244.77,
#   'open': 6277.73,
#   'volumefrom': 177320.05,
#   'volumeto': 1190524168.21,
#   'close': 6612.36,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539648000,
#   'high': 6724.91,
#   'low': 6545.54,
#   'open': 6612.69,
#   'volumefrom': 49191.34,
#   'volumeto': 324232509.78,
#   'close': 6583.05,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539734400,
#   'high': 6589.2,
#   'low': 6511.6,
#   'open': 6583.05,
#   'volumefrom': 33538.55,
#   'volumeto': 220418636.64,
#   'close': 6574.52,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539820800,
#   'high': 6616.27,
#   'low': 6445.05,
#   'open': 6576.4,
#   'volumefrom': 50725.31,
#   'volumeto': 331761115.45,
#   'close': 6488.72,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539907200,
#   'high': 6503.09,
#   'low': 6449.36,
#   'open': 6489.37,
#   'volumefrom': 36599.64,
#   'volumeto': 237855085.41,
#   'close': 6469.28,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1539993600,
#   'high': 6645.2,
#   'low': 6395.45,
#   'open': 6469.28,
#   'volumefrom': 19543.75,
#   'volumeto': 127185847.78,
#   'close': 6490.56,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1540080000,
#   'high': 6557.39,
#   'low': 6474.47,
#   'open': 6490.6,
#   'volumefrom': 16019.49,
#   'volumeto': 105283929.06,
#   'close': 6509.87,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#
#  ('2018/09/03', 7270.05),
#  ('2018/09/04', 7369.86),
#  ('2018/09/05', 6705.03),
#  ('2018/09/06', 6515.42),
#  ('2018/09/07', 6411.78),
#  ('2018/09/08', 6200.16),
#  ('2018/09/09', 6249.07),
#  ('2018/09/10', 6324.43),
#  ('2018/09/11', 6295.54),
#  ('2018/09/12', 6337.11),
#  ('2018/09/13', 6492),
#  ('2018/09/14', 6486.01),
#  ('2018/09/15', 6522.08),
#  ('2018/09/16', 6502.44),
#  ('2018/09/17', 6261.48),
#  ('2018/09/18', 6346.44),
#  ('2018/09/19', 6398.8),
#  ('2018/09/20', 6505.9),
#  ('2018/09/21', 6762.06),
#  ('2018/09/22', 6716.6),
#  ('2018/09/23', 6702.7),
#  ('2018/09/24', 6583.53),
#  ('2018/09/25', 6437.74),
#  ('2018/09/26', 6462.6),
#  ('2018/09/27', 6686.13),
#  ('2018/09/28', 6635.38),
#  ('2018/09/29', 6603.75),
#  ('2018/09/30', 6623.71),
#  ('2018/10/01', 6594.98),
#  ('2018/10/02', 6525.47),
#  ('2018/10/03', 6492.26),
#  ('2018/10/04', 6579.79),
#  ('2018/10/05', 6632.87),
#  ('2018/10/06', 6589.94),
#  ('2018/10/07', 6601.15),
#  ('2018/10/08', 6650.07),
#  ('2018/10/09', 6631.79),
#  ('2018/10/10', 6581.07),
#  ('2018/10/11', 6209.47),
#  ('2018/10/12', 6250.85),
#  ('2018/10/13', 6267.27),
#  ('2018/10/14', 6277.73),
#  ('2018/10/15', 6612.36),
#  ('2018/10/16', 6583.05),
#  ('2018/10/17', 6574.52),
#  ('2018/10/18', 6488.72),
#  ('2018/10/19', 6469.28),
#  ('2018/10/20', 6490.56),
#  ('2018/10/21', 6509.87),
#  ('2018/10/22', 6483.23),
#  ...]

# %%
BTC=pd.DataFrame(rows)
BTC.columns=['date','close price']
BTC['date']=pd.to_datetime(BTC['date'])
BTC.head()
# Out:
#         date  close price
# 0 2016-01-27       395.02
# 1 2016-01-28       379.69
# 2 2016-01-29       380.29
# 3 2016-01-30       377.76
# 4 2016-01-31       369.84

# %%
table=pd.merge(BTC,Ibm,left_on='date',right_on='Date')
table=table[['date','close price','Adj_Close']]
table=table.set_index(['date'])
table.head()
# Out:
#             close price  Adj_Close
# date
# 2016-01-27       395.02  93.876375
# 2016-01-28       379.69  94.854254
# 2016-01-29       380.29  96.848817
# 2016-02-01       372.18  96.879860
# 2016-02-02       373.92  95.413042

# %%
xt=table['close price'].values.tolist()
yt=table['Adj_Close'].values.tolist()

# %%
x = np.asarray(xt)
x
# Out:
# array([  395.02,   379.69,   380.29,   372.18,   373.92,   368.02,
#          390.65,   386.46,   372.63,   375.32,   381.88,   379.45,
#          384.04,   406.42,   417.14,   421.4 ,   419.98,   437.79,
#          419.9 ,   422.72,   423.48,   427.32,   436.21,   434.04,
#          425.36,   419.56,   409.48,   414.87,   411.9 ,   412.76,
#          415.83,   419.11,   414.31,   415.13,   415.91,   418.16,
#          408.16,   411.11,   416.21,   416.98,   414.74,   422.21,
#        127.89461279, 127.6460485 , 127.62119207, 127.05777968,
#        125.59125037, 124.97812512, 125.40068441, 125.58296489,
#        125.77353085, 124.81955995, 124.18357936, 124.59361948,
#        123.09571781, 124.78608729, 124.6605648 , 125.94926233,
#        127.15427819, 127.00365121, 127.06222837, 127.17938269,
#        127.58942281, 128.49318471, 128.84464767, 129.50573276,
#        130.92832093, 129.99945454, 128.95343382, 128.50992104,
#        129.54757359, 130.04966353, 131.16262957, 128.79443867,
#        128.86975216, 127.61452731, 128.30908506, 128.2254034 ,
#        127.99109476, 126.77771073, 127.61452731, 127.89067677,
#        128.14172175, 128.90322483])

# %%
x = (x - np.mean(x))/(np.std(x))
y = (y - np.mean(y))/(np.std(y))

# %%
beta = ((np.multiply(y, x)).mean()-np.mean(x)*np.mean(y))/((np.multiply(x, x)).mean()-np.mean(x)*np.mean(x))
alpha =np.mean(y)-beta*np.mean(x)
print("alpha =",alpha, "\nbeta =",beta)
# Out:
# alpha = -2.40514245600833e-16
# beta = 0.07513237133588946

# %%
def  cal_cost(beta0,beta1,x,y):
        n = len(y)
        predictions = beta0 + np.multiply(beta1,x)
        cost = (1/2*n) * np.sum(np.square(predictions-y))
        return cost

# %%
cal_cost(alpha,beta,x,y)
# Out:
# 117431.35176216281

# %%
cal_cost(0,beta,x,y)
# Out:
# 117431.35176216281

# %%
iterations = 500
alpha = -1
n = len(y)

loss_history = np.zeros((iterations,1))
alpha_history = np.zeros((iterations,1))

for i in range(iterations):
    
        
        prediction = alpha + np.multiply(beta,x)
        residuals = y-prediction
        residuals_sum = sum(residuals)
        gradient = -(1/n)*0.1*residuals_sum
 
        alpha = alpha - gradient
    
        loss_history[i] = cal_cost(alpha,beta,x,y)
        alpha_history[i] = alpha
    
plt.plot(alpha_history,loss_history,'go')

# %%
iterations = 1000
learningrate = 0.02
beta0 = -1
beta1 = 0
n = len(y)
index = np.arange(1, iterations+1, 1).reshape((iterations, 1))

loss_history = np.zeros((iterations,1))
beta0_history = np.zeros((iterations,1))
beta1_history = np.zeros((iterations,1))

for i in range(iterations):
       
        prediction = beta0 + np.multiply(beta1,x)
        residuals = y-prediction
        residuals_sum = sum(residuals)
        beta0_gradient = -(1/n)*residuals_sum*(learningrate)
        beta0 = beta0 - beta0_gradient
        beta0_history[i] = beta0
    
        residuals_x = np.multiply(residuals,x)
        residuals_x_sum = sum(residuals_x)
        beta1_gradient = -(1/n)*residuals_x_sum*(learningrate)
        beta1 = beta1 - beta1_gradient
        beta1_history[i] = beta1
    
        loss_history[i] = cal_cost(beta0,beta1,x,y)

# %%
plt.plot(beta1_history,loss_history,'go')

# %%
plt.plot(x,y,'go')

# %%
plt.subplot(311)
plt.plot(index, beta0_history,'go')
plt.subplot(312)
plt.plot(index, beta1_history,'go')
plt.subplot(313)
plt.plot(index, loss_history,'go')

# %%
beta0_history.min()
# Out:
# -0.98

# %% [markdown]
# alpha = zero
# beta = 0.07513237133588946
# gradient learning rate is 0.02, with 1000 iterations the same estimated alpha and beta values are found out.
